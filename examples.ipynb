# %%
pip install numpy matplotlib jupyter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from maze_solver.maze import Maze
import os

# %%
maze1 = Maze()
maze1.load_from_csv("data/maze_1.csv")
maze1.build_graph()
path1 = maze1.find_shortest_path()

if path1:
    maze1.save_image(path1, filename="images/vysledek_1.png")
else:
    print("V bludišti 1 nelze najít cestu.")

# %%
maze2 = Maze()
maze2.load_from_csv("data/maze_2.csv")
maze2.build_graph()
path2 = maze2.find_shortest_path()

if path2:
    maze2.save_image(path2, filename="images/vysledek_2.png")
else:
    print("V bludišti 2 nelze najít cestu.")

# %%
maze3 = Maze()
maze3.load_from_csv("data/maze_3.csv")
maze3.build_graph()
path3 = maze3.find_shortest_path()

if path3:
    maze3.save_image(path3, filename="images/vysledek_3.png")
else:
    print("V bludišti 3 nelze najít cestu.")

# %%
maze4 = Maze()
maze4.load_from_csv("data/maze_4.csv")
maze4.build_graph()
path4 = maze4.find_shortest_path()

if path4:
    maze4.save_image(path4, filename="images/vysledek_4.png")
else:
    print("V bludišti 4 nelze najít cestu.")

# %%
maze5 = Maze()
maze5.load_from_csv("data/maze_5.csv")
maze5.build_graph()
path5 = maze5.find_shortest_path()

if path5:
    maze5.save_image(path5, filename="images/vysledek_5.png")
else:
    print("V bludišti 5 nelze najít cestu.")

# %%
random_maze = Maze()

random_maze.generate_maze(size=15, wall=0.3)

random_maze.build_graph()

path_random = random_maze.find_shortest_path()

random_maze.save_image(path_random, filename="images/random_vysledek.png")
